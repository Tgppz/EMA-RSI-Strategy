# %% [markdown]
# # EMA + RSI Multi-Pair Strategy
# Notebook นี้เป็นตัวอย่างการรันกลยุทธ์ EMA + RSI หลายคู่เงินบน Google Colab

# %%
# ตัวอย่างโค้ดเริ่มต้น
print('เริ่มกลยุทธ์ EMA + RSI หลายคู่เงิน...')
